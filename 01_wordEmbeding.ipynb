# %%
from tensorflow.keras.preprocessing.text import one_hot

# %%
sent=[
    'I love my country',
    'I love my city',
    'the glass of water is full',
    'the glass of water is empty',
    'I am a good boy'
]

# %%
voc_size=10000

onehot_repr=[one_hot(words,voc_size) for words in sent]
onehot_repr
# Out:
# [[2450, 4523, 1389, 734],
#  [2450, 4523, 1389, 8268],
#  [8936, 7768, 1259, 5644, 45, 6106],
#  [8936, 7768, 1259, 5644, 45, 8823],
#  [2450, 1480, 4140, 943, 2487]]

# %%
#word emading representation
from tensorflow.keras.layers import Embedding
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.models import Sequential

# %%
import numpy as np

# %%
sent_length=8
embedded_docs=pad_sequences(onehot_repr,padding='pre',maxlen=sent_length)
print(embedded_docs)
# Out:
# [[   0    0    0    0 2450 4523 1389  734]
#  [   0    0    0    0 2450 4523 1389 8268]
#  [   0    0 8936 7768 1259 5644   45 6106]
#  [   0    0 8936 7768 1259 5644   45 8823]
#  [   0    0    0 2450 1480 4140  943 2487]]

# %%
#feature representation
dim=10
model=Sequential()
model.add(Embedding(voc_size,dim,input_length=sent_length))
model.compile('adam','mse')

# %%
model.summary()
# Out:
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ embedding_1 (Embedding)         │ ?                      │   0 (unbuilt) │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 0 (0.00 B)
#  Trainable params: 0 (0.00 B)
#  Non-trainable params: 0 (0.00 B)

# %%
model.predict(embedded_docs)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 181ms/step
# array([[[ 0.01685048, -0.0041257 , -0.02226426,  0.04113745,
#           0.00773195,  0.02713526,  0.0426852 ,  0.03185115,
#          -0.01980497, -0.01789763],
#         [ 0.01685048, -0.0041257 , -0.02226426,  0.04113745,
#           0.00773195,  0.02713526,  0.0426852 ,  0.03185115,
#          -0.01980497, -0.01789763],
#         [ 0.01685048, -0.0041257 , -0.02226426,  0.04113745,
#           0.00773195,  0.02713526,  0.0426852 ,  0.03185115,
#          -0.01980497, -0.01789763],
#         [ 0.01685048, -0.0041257 , -0.02226426,  0.04113745,
#           0.00773195,  0.02713526,  0.0426852 ,  0.03185115,
#          -0.01980497, -0.01789763],
#         [-0.00777727, -0.02367663, -0.04468043, -0.02077444,
#          -0.02567064,  0.03780473,  0.00865819, -0.04077847,
#          -0.02798656, -0.0470642 ],
#         [ 0.03342668, -0.0292163 ,  0.01096056,  0.01516146,
#           0.03926129,  0.02513951,  0.01281111, -0.04967461,
#           0.04232221,  0.02094007],
#         [ 0.00354246,  0.00141597, -0.03963454,  0.02147478,
#          -0.03880547, -0.01280994, -0.04374428, -0.02261629,
#           0.01789086,  0.02176854],
#         [-0.01638335,  0.02130181,  0.02660784, -0.0397792 ,
#           0.02924922, -0.01128132, -0.00040944, -0.04845314,
#           0.019338  , -0.02297602]],
#
#        [[ 0.01685048, -0.0041257 , -0.02226426,  0.04113745,
#           0.00773195,  0.02713526,  0.0426852 ,  0.03185115,
#          -0.01980497, -0.01789763],
#         [ 0.01685048, -0.0041257 , -0.02226426,  0.04113745,
#           0.00773195,  0.02713526,  0.0426852 ,  0.03185115,
#          -0.01980497, -0.01789763],
#         [ 0.01685048, -0.0041257 , -0.02226426,  0.04113745,
#           0.00773195,  0.02713526,  0.0426852 ,  0.03185115,
#          -0.01980497, -0.01789763],
#         [ 0.01685048, -0.0041257 , -0.02226426,  0.04113745,
#           0.00773195,  0.02713526,  0.0426852 ,  0.03185115,
#          -0.01980497, -0.01789763],
#         [-0.00777727, -0.02367663, -0.04468043, -0.02077444,
#          -0.02567064,  0.03780473,  0.00865819, -0.04077847,
#          -0.02798656, -0.0470642 ],
#         [ 0.03342668, -0.0292163 ,  0.01096056,  0.01516146,
#           0.03926129,  0.02513951,  0.01281111, -0.04967461,
#           0.04232221,  0.02094007],
#         [ 0.00354246,  0.00141597, -0.03963454,  0.02147478,
#          -0.03880547, -0.01280994, -0.04374428, -0.02261629,
#           0.01789086,  0.02176854],
#         [-0.02382814,  0.04117645, -0.01729004, -0.01201893,
#           0.04719671, -0.01093913,  0.03587079,  0.04207996,
#          -0.01584544, -0.03897892]],
#
#        [[ 0.01685048, -0.0041257 , -0.02226426,  0.04113745,
#           0.00773195,  0.02713526,  0.0426852 ,  0.03185115,
#          -0.01980497, -0.01789763],
#         [ 0.01685048, -0.0041257 , -0.02226426,  0.04113745,
#           0.00773195,  0.02713526,  0.0426852 ,  0.03185115,
#          -0.01980497, -0.01789763],
#         [ 0.00595777,  0.0133616 ,  0.04817441,  0.01194606,
#           0.04800253, -0.04289341,  0.04423959, -0.03545268,
#           0.01319667,  0.01762146],
#         [-0.00408142, -0.04780036, -0.01799072,  0.03449566,
#           0.01716952, -0.0471457 , -0.00969984,  0.01698763,
#           0.04864645, -0.00666947],
#         [-0.04477736,  0.04042863, -0.01770704,  0.02665308,
#          -0.0425967 , -0.03347428,  0.04551742,  0.04643332,
#           0.02027822, -0.04408477],
#         [ 0.01888413,  0.00669773, -0.00414027,  0.0335119 ,
#          -0.00478243, -0.01448804, -0.02473651,  0.01767008,
#          -0.01906426,  0.03340447],
#         [-0.03698553, -0.04886115, -0.02687438, -0.00090504,
#           0.04838537, -0.03046047,  0.02722322, -0.00082824,
#           0.02207683,  0.00707289],
#         [-0.04444353,  0.02021805, -0.02707908,  0.0487758 ,
#           0.00555422,  0.04073666,  0.00761594,  0.01506015,
#           0.04843805, -0.01176907]],
#
#        [[ 0.01685048, -0.0041257 , -0.02226426,  0.04113745,
#           0.00773195,  0.02713526,  0.0426852 ,  0.03185115,
#          -0.01980497, -0.01789763],
#         [ 0.01685048, -0.0041257 , -0.02226426,  0.04113745,
#           0.00773195,  0.02713526,  0.0426852 ,  0.03185115,
#          -0.01980497, -0.01789763],
#         [ 0.00595777,  0.0133616 ,  0.04817441,  0.01194606,
#           0.04800253, -0.04289341,  0.04423959, -0.03545268,
#           0.01319667,  0.01762146],
#         [-0.00408142, -0.04780036, -0.01799072,  0.03449566,
#           0.01716952, -0.0471457 , -0.00969984,  0.01698763,
#           0.04864645, -0.00666947],
#         [-0.04477736,  0.04042863, -0.01770704,  0.02665308,
#          -0.0425967 , -0.03347428,  0.04551742,  0.04643332,
#           0.02027822, -0.04408477],
#         [ 0.01888413,  0.00669773, -0.00414027,  0.0335119 ,
#          -0.00478243, -0.01448804, -0.02473651,  0.01767008,
#          -0.01906426,  0.03340447],
#         [-0.03698553, -0.04886115, -0.02687438, -0.00090504,
#           0.04838537, -0.03046047,  0.02722322, -0.00082824,
#           0.02207683,  0.00707289],
#         [ 0.01364755,  0.01588441, -0.01128931, -0.04431688,
#          -0.01755686, -0.04769237, -0.0161206 , -0.01378573,
#           0.04712943, -0.042902  ]],
#
#        [[ 0.01685048, -0.0041257 , -0.02226426,  0.04113745,
#           0.00773195,  0.02713526,  0.0426852 ,  0.03185115,
#          -0.01980497, -0.01789763],
#         [ 0.01685048, -0.0041257 , -0.02226426,  0.04113745,
#           0.00773195,  0.02713526,  0.0426852 ,  0.03185115,
#          -0.01980497, -0.01789763],
#         [ 0.01685048, -0.0041257 , -0.02226426,  0.04113745,
#           0.00773195,  0.02713526,  0.0426852 ,  0.03185115,
#          -0.01980497, -0.01789763],
#         [-0.00777727, -0.02367663, -0.04468043, -0.02077444,
#          -0.02567064,  0.03780473,  0.00865819, -0.04077847,
#          -0.02798656, -0.0470642 ],
#         [ 0.00906764,  0.04648676, -0.01181871,  0.02330274,
#           0.03333689,  0.00192658, -0.03901924, -0.04918127,
#           0.00166605, -0.01474207],
#         [ 0.01481453, -0.03039004,  0.01529676,  0.03001454,
#          -0.0251013 ,  0.01861458, -0.0129174 , -0.00471878,
#          -0.02168264,  0.01860763],
#         [ 0.04898807, -0.03625797,  0.01613266,  0.02976972,
#          -0.04700264, -0.01333342, -0.04953137, -0.02146556,
#          -0.02150387,  0.01845356],
#         [-0.03076805,  0.04693631, -0.03708197, -0.01537582,
#           0.00505022, -0.00130155, -0.01935729, -0.02802117,
#           0.028715  ,  0.02149886]]], dtype=float32)

# %%
i
